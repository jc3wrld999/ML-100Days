# %% [markdown]
# ## 로지스틱 회귀
#
# 마케팅 팀은 럭키백에 들어있는 생선의 확률을 알려주는 방향으로 이벤트를 내놓았다. A 럭키백에 도미 확률이 높다고 표시하면 도미를 원한 고객은 A 럭키백을 선택할 것이다. 여기서 생선의 확률을 머신러닝으로 구해보자.
#
# - 럭키백에 들어간 생선은 7종류
# - 생선의 길이, 두께, 높이, 대각선 길이, 무게 가 주어짐

# %% [markdown]
# ### 알고리즘 선택
# - 확률은 숫자니까 회귀를 써야하는지 7개의 생선에 대한 문제니까 분류를 써야 하는지 애매
# - knn은 주변 이웃을 찾아주니까 이웃의 클래스 비율을 확률이라고 출력해보자
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 데이터 셋 준비

# %%
import pandas as pd
fish = pd.read_csv('https://bit.ly/fish_csv_data')
fish.head()
